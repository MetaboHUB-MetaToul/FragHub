# %% [markdown]
# ![image.png](attachment:5c949e78-df47-498b-9a84-668fc3d2b2b4.png)

# %% [markdown]
# ![image.png](attachment:4e11beca-ce3c-4855-97e4-dd8b9aa23463.png)

# %% [markdown]
# ![image.png](attachment:83cf099b-9f2a-4ccb-b4f5-aec29b749cd4.png)

# %% [markdown]
# ![image.png](attachment:50fd61bd-1e6d-4e87-ab30-4af4e1a0c622.png)
