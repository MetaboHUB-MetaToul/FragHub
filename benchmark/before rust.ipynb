# %% [markdown]
# ![image.png](attachment:443a92a4-4762-47f2-9b6b-7de6b3e9476d.png)

# %% [markdown]
# ![image.png](attachment:a302a876-4362-4fba-94b4-a48ae9c94af3.png)

# %% [markdown]
# ![image.png](attachment:2e80a689-e555-4257-87c0-19fc749d1bf6.png)

# %% [markdown]
# ![image.png](attachment:67a846f7-c7f3-4891-952a-b7ae1c7656aa.png)

# %% [markdown]
# ![image.png](attachment:26b37623-f67f-4ff8-ad0d-8b0c24d6d026.png)

# %% [markdown]
# ![image.png](attachment:2c83729e-b1d4-4951-8632-bf3b97f2a03a.png)
# ![image.png](attachment:f3c23c1c-1ceb-4c12-be7a-abecb6714cba.png)

# %% [markdown]
# ![image.png](attachment:61eda719-e9ed-4f5b-b81e-61e17e173c2e.png)

# %% [markdown]
# ![image.png](attachment:eb3d89e8-baf0-41f0-8f84-d04cd591d759.png)

# %% [markdown]
# ![image.png](attachment:ff1ed4e3-c4da-4627-b7ec-95c67ce4126e.png)
